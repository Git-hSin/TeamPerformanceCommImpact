# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
from us import states

from config import akey
c = Census(akey)

# %%
# Import Sports Data

mlb_data_file = "Resources/mlb.csv"
mlb_attendance_file = "Resources/mlb_attendance.csv"
mlb_locations_file = "Resources/mlb_loc.csv"
nfl_data_file = "Resources/nfl.csv"
nfl_attendance_file = "Resources/nfl_attendance.csv"
nfl_locations_file = "Resources/nfl_loc.csv"
nba_data_file = "Resources/nba.csv"
nba_attendance_file = "Resources/nba_attendance.csv"
nba_locations_file = "Resources/nba_loc.csv"

mlb_df = pd.read_csv(mlb_data_file, low_memory = False)
mlb_attendance_df = pd.read_csv(mlb_attendance_file, low_memory = False)
mlb_locations_df = pd.read_csv(mlb_locations_file, low_memory = False)
nfl_df = pd.read_csv(nfl_data_file, low_memory = False)
nfl_attendance_df = pd.read_csv(nfl_attendance_file, low_memory = False)
nfl_location_df = pd.read_csv(nfl_locations_file, low_memory = False)
nba_df = pd.read_csv(nba_data_file, low_memory = False)
nba_attendance_df = pd.read_csv(nba_attendance_file, low_memory = False)
nba_locations_df = pd.read_csv(nba_locations_file, low_memory = False)

# %%
nfl_location_df = pd.read_csv(nfl_locations_file, dtype = {'State Name':'str',
                                                          'NFL Team(s)':'str',
                                                          'Stadium City':'str',
                                                          'Zip Codes':'str'}, low_memory = False)

# %%
nfl_location_df
# Out:
#         State Name           NFL Team(s)        Stadium City Zip Codes  \
# 0          Arizona     Arizona Cardinals         Glendale,AZ     85305
# 1       California      Los Angeles Rams     Los Angeles, CA     90037
# 2       California  Los Angeles Chargers           Carson,CA     90746
# 3       California       Oakland Raiders          Oakland,CA     94621
# 4       California   San Francisco 49ers      Santa Clara,CA     95054
# 5         Colorado        Denver Broncos           Denver,CO     80204
# 6          Florida  Jacksonville Jaguars     Jacksonville,FL     32202
# 7          Florida        Miami Dolphins    Miami Gardens,FL     33056
# 8          Florida  Tampa Bay Buccaneers            Tampa,FL     33607
# 9          Georgia       Atlanta Falcons          Atlanta,GA     30313
# 10        Illinois         Chicago Bears          Chicago,IL     60605
# 11         Indiana    Indianapolis Colts     Indianapolis,IN     46225
# ...

# %%
url = 'https://api.census.gov/data/2016/acs/acs5/subject?get=NAME,S1902_C01_001E,S2409_C05_006E&for=zip%20code%20tabulation%20area:*'
#url = 'https://api.census.gov/data/2016/acs/acs5/subject/groups/S2409
urlbeg = 'https://api.census.gov/data/'
urlend = '/acs/acs5/subject?get=NAME,S1902_C01_001E,S2409_C05_006E&for=zip%20code%20tabulation%20area:*'

url_list = []
reports_list =  []

reports = ['S1902_C01_001E', 'S2409_C05_006E']
reportnames = ['PercentFemaleEmployed','EstMeanIncAll']
years = ['2016', '2017']




for year in years:
    url_list.append(urlbeg + year + urlend)

    
for url in url_list:
    reports_list.append(requests.get(url).json())    

#for report in reports:
#    reports_list.append(urlmid + report + urlend)

#print(url_list)
#print(reports_list)
#response = requests.get(f"{url}&q={city}").json()

# %%
estimate = pd.DataFrame([[g[3], g[2], g[1]] for g in reports_list[0]][1:], columns = ['zip'] + reportnames)

# %%
estimate.EstMeanIncAll = estimate.EstMeanIncAll.astype(int)

# %%
print(estimate)
# Out:
#          zip PercentFemaleEmployed  EstMeanIncAll
# 0      01001                  53.7           7190
# 1      01002                  50.6           9561
# 2      01003          -666666666.0             26
# 3      01005                   0.0           1840
# 4      01007                  64.8           5611
# 5      01008                  58.5            530
# 6      01009          -666666666.0            106
# 7      01010                  25.6           1494
# 8      01011                  65.8            552
# 9      01012                  40.6            243
# 10     01013                  60.4           9302
# 11     01020                  50.1          12482
# 12     01022                 100.0           1204
# 13     01026                  30.0            455
# 14     01027                  54.5           7883
# 15     01028                  39.5           6063
# 16     01029                  60.0            325
# 17     01030                  67.2           4431
# ...

# %%
# nfl_location_df['Zip Codes'] = nfl_location_df['Zip Codes'].astype('str')
estimate['zip'] = estimate['zip'].astype('str')

# %%
pd.merge(estimate, nfl_location_df, left_on = 'zip', right_on = 'Zip Codes').sort_values('EstMeanIncAll')
# Out:
#       zip PercentFemaleEmployed  EstMeanIncAll      State Name  \
# 10  37213          -666666666.0              0       Tennessee
# 28  98134                 100.0            199      Washington
# 16  55415                  69.8           1404       Minnesota
# 19  70112                 100.0           1549       Louisiana
# 7   32202                  63.2           1686         Florida
# 6   30313                  16.0           2011         Georgia
# 13  46225                  88.3           2677         Indiana
# 11  44114                   6.4           3515            Ohio
# 14  48226                  64.7           3799        Michigan
# 18  64129                  62.3           3816        Missouri
# 23  85305                  61.2           4351         Arizona
# 5   28202                  57.2           6407  North Carolina
# 12  45202                  35.8           7539            Ohio
# 25  90746                  64.5           8118      California
# ...

# %%
print(group[0:2])
# Out:
# [['NAME', 'S1902_C01_001E', 'S2409_C05_006E', 'zip code tabulation area'], ['ZCTA5 01001', '7190', '53.7', '01001']]

# %%
print(response)
pd.DataFrame({
    "Years" : Years ,
    "Reports": Reports ,
    })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-38d6be894ac0> in <module>
# ----> 1 print(response)
#       2 pd.DataFrame({
#       3     "Years" : Years ,
#       4     "Reports": Reports ,
#       5     })
#
# NameError: name 'response' is not defined

# %% [markdown]
# ### Looping Through Census Calls
#
# For each report, pass through the data and group by zip codes for each report as a dataset.

# %%
# Out:
#          zip PercentFemaleEmployed  EstMeanIncAll
# 0      01001                  53.7           7190
# 1      01002                  50.6           9561
# 2      01003          -666666666.0             26
# 3      01005                   0.0           1840
# 4      01007                  64.8           5611
# 5      01008                  58.5            530
# 6      01009          -666666666.0            106
# 7      01010                  25.6           1494
# 8      01011                  65.8            552
# 9      01012                  40.6            243
# 10     01013                  60.4           9302
# 11     01020                  50.1          12482
# 12     01022                 100.0           1204
# 13     01026                  30.0            455
# 14     01027                  54.5           7883
# 15     01028                  39.5           6063
# 16     01029                  60.0            325
# 17     01030                  67.2           4431
# ...

# %%
# Out:
#       zip PercentFemaleEmployed  EstMeanIncAll      State Name  \
# 10  37213          -666666666.0              0       Tennessee
# 28  98134                 100.0            199      Washington
# 16  55415                  69.8           1404       Minnesota
# 19  70112                 100.0           1549       Louisiana
# 7   32202                  63.2           1686         Florida
# 6   30313                  16.0           2011         Georgia
# 13  46225                  88.3           2677         Indiana
# 11  44114                   6.4           3515            Ohio
# 14  48226                  64.7           3799        Michigan
# 18  64129                  62.3           3816        Missouri
# 23  85305                  61.2           4351         Arizona
# 5   28202                  57.2           6407  North Carolina
# 12  45202                  35.8           7539            Ohio
# 25  90746                  64.5           8118      California
# ...

# %%
tabs = c.acs5.tables()
check = [tabs[i]['name'] for i in range(len(tabs))]
pd.Series([check[j][0] if check[j][0] == 'S' else None for j in range(len(check))]).notnull().sum()
# Out:
# 0

# %%
odata = c.acs5.get(("NAME", "S1902"), {'for': 'state:24'})
# Out:
# -------------------------------------
# CensusExceptionTraceback (most recent call last)
# <ipython-input-26-1c81171bd580> in <module>()
# ----> 1 odata = c.acs5.get(("NAME", "S1902"), {'for': 'state:24'})
#
# ~/anaconda3/lib/python3.6/site-packages/census/core.py in get(self, *args, **kwargs)
#     296         self._switch_endpoints(kwargs.get('year', self.default_year))
#     297
# --> 298         return super(ACSClient, self).get(*args, **kwargs)
#     299
#     300 class ACS5Client(ACSClient):
#
# ~/anaconda3/lib/python3.6/site-packages/census/core.py in get(self, fields, geo, year, **kwargs)
#     153         all_results = (self.query(fifty_fields, geo, year, **kwargs)
#     154                        for fifty_fields in chunks(fields, 50))
# --> 155         merged_results = [merge(result) for result in zip(*all_results)]
#     156
#     157         return merged_results
#
# ~/anaconda3/lib/python3.6/site-packages/census/core.py in <genexpr>(.0)
# ...

# %%
cdata
# Out:
# [{'B01002_001E': 38.9,
#   'B01003_001E': 17599.0,
#   'B19013_001E': 11757.0,
#   'B19301_001E': 7041.0,
#   'NAME': 'ZCTA5 00601',
#   'zip code tabulation area': '00601'},
#  {'B01002_001E': 40.9,
#   'B01003_001E': 39209.0,
#   'B19013_001E': 16190.0,
#   'B19301_001E': 8978.0,
#   'NAME': 'ZCTA5 00602',
#   'zip code tabulation area': '00602'},
#  {'B01002_001E': 40.4,
#   'B01003_001E': 50135.0,
#   'B19013_001E': 16645.0,
#   'B19301_001E': 10897.0,
#   'NAME': 'ZCTA5 00603',
#   'zip code tabulation area': '00603'},
#  {'B01002_001E': 42.8,
#   'B01003_001E': 6304.0,
#   'B19013_001E': 13387.0,
#   'B19301_001E': 5960.0,
#   'NAME': 'ZCTA5 00606',
#   'zip code tabulation area': '00606'},
#  {'B01002_001E': 41.4,
#   'B01003_001E': 27590.0,
#   'B19013_001E': 18741.0,
#   'B19301_001E': 9266.0,
#   'NAME': 'ZCTA5 00610',
#   'zip code tabulation area': '00610'},
#  {'B01002_001E': 41.4,
#   'B01003_001E': 62566.0,
#   'B19013_001E': 17744.0,
#   'B19301_001E': 10283.0,
# ...

# %%
cdata = c.acs5.get(("NAME", "B01003_001E", "B01002_001E", "B19013_001E", "B19301_001E" 
                   ), {'for': 'zip code tabulation area:*'})

odata = c.acs5.get(("NAME", "S1902_001E" 
                   ), {'for': 'zip code tabulation area:*'})

cdatadf = pd.DataFrame(cdata)

odatadf = pd.DataFrame(odata)

# Column Reordering
census_pd = cdatadf.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "NAME": "Name", "state": "State"})
# Out:
# ---------------------------------------------------------------------------
# CensusException                           Traceback (most recent call last)
# <ipython-input-18-2b00f46ae710> in <module>()
#       3
#       4 odata = c.acs5.get(("NAME", "S1902_001E"
# ----> 5                    ), {'for': 'zip code tabulation area:*'})
#       6
#       7 cdatadf = pd.DataFrame(cdata)
#
# ~\Anaconda3\envs\PythonDat@\lib\site-packages\census\core.py in get(self, *args, **kwargs)
#     296         self._switch_endpoints(kwargs.get('year', self.default_year))
#     297
# --> 298         return super(ACSClient, self).get(*args, **kwargs)
#     299
#     300 class ACS5Client(ACSClient):
#
# ~\Anaconda3\envs\PythonDat@\lib\site-packages\census\core.py in get(self, fields, geo, year, **kwargs)
#     153         all_results = (self.query(fifty_fields, geo, year, **kwargs)
#     154                        for fifty_fields in chunks(fields, 50))
# ...

# %%
cdatadf.head()
# Out:
#    B01002_001E  B01003_001E  B19013_001E  B19301_001E         NAME  \
# 0         38.9      17599.0      11757.0       7041.0  ZCTA5 00601
# 1         40.9      39209.0      16190.0       8978.0  ZCTA5 00602
# 2         40.4      50135.0      16645.0      10897.0  ZCTA5 00603
# 3         42.8       6304.0      13387.0       5960.0  ZCTA5 00606
# 4         41.4      27590.0      18741.0       9266.0  ZCTA5 00610
#
#   zip code tabulation area
# 0                    00601
# 1                    00602
# 2                    00603
# 3                    00606
# 4                    00610

# %%
c.acs5.tables()
# Out:
# [{'name': 'B07012',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY POVERTY STATUS IN THE PAST 12 MONTHS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2017/acs/acs5/groups/B07012.json'},
#  {'name': 'B07013',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY TENURE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2017/acs/acs5/groups/B07013.json'},
#  {'name': 'B13002A',
#   'description': 'WOMEN 15 TO 50 YEARS WHO HAD A BIRTH IN THE PAST 12 MONTHS BY MARITAL STATUS (WHITE ALONE)',
#   'variables': 'https://api.census.gov/data/2017/acs/acs5/groups/B13002A.json'},
#  {'name': 'B13002C',
#   'description': 'WOMEN 15 TO 50 YEARS WHO HAD A BIRTH IN THE PAST 12 MONTHS BY MARITAL STATUS (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'variables': 'https://api.census.gov/data/2017/acs/acs5/groups/B13002C.json'},
#  {'name': 'B13002B',
# ...

# %%
cdata = c.acs5.get(("NAME", "B07003_001E" 
                   ), {'for': 'zip code tabulation area:*'})

# %%
d = pd.DataFrame(cdata)

d.head()
# Out:
#    B07003_001E         NAME zip code tabulation area
# 0        335.0  ZCTA5 84306                    84306
# 1        411.0  ZCTA5 84775                    84775
# 2        211.0  ZCTA5 84762                    84762
# 3        203.0  ZCTA5 84772                    84772
# 4        224.0  ZCTA5 84781                    84781
